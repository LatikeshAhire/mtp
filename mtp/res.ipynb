# %%
res=[{'epoch': 0, 'psnr': 18.053933875993916, 'ssim': 0.7031761485157249}, {'epoch': 0, 'psnr': 16.471257339508547, 'ssim': 0.673954187194215}, {'epoch': 1, 'psnr': 18.735616535236986, 'ssim': 0.7396650977460101}, {'epoch': 1, 'psnr': 19.70180800811794, 'ssim': 0.7446715583438748}, {'epoch': 2, 'psnr': 20.81536720112569, 'ssim': 0.7538654233924098}, {'epoch': 2, 'psnr': 20.444668927912414, 'ssim': 0.7348804002427751}, {'epoch': 3, 'psnr': 21.145887614721566, 'ssim': 0.7584469276227251}, {'epoch': 3, 'psnr': 23.74145451011649, 'ssim': 0.7702003289176464}, {'epoch': 4, 'psnr': 25.411837184104936, 'ssim': 0.8087887088567026}, {'epoch': 4, 'psnr': 23.889339218921908, 'ssim': 0.7687915197151933}, {'epoch': 5, 'psnr': 25.12325479179926, 'ssim': 0.7916218233197662}, {'epoch': 5, 'psnr': 16.6378309755444, 'ssim': 0.5915118694129742}, {'epoch': 6, 'psnr': 24.000596152346304, 'ssim': 0.7788140024658886}, {'epoch': 6, 'psnr': 24.237361986600888, 'ssim': 0.7774777836891367}, {'epoch': 7, 'psnr': 25.641921562037695, 'ssim': 0.7969321001258501}, {'epoch': 7, 'psnr': 24.450381043908468, 'ssim': 0.7798586496037452}, {'epoch': 8, 'psnr': 25.837776228520195, 'ssim': 0.7904968352551703}, {'epoch': 8, 'psnr': 24.29951807065927, 'ssim': 0.7641749708252349}, {'epoch': 9, 'psnr': 25.125338534602342, 'ssim': 0.7853149153482785}, {'epoch': 9, 'psnr': 24.355034725268993, 'ssim': 0.7762742930138206}]

# %%
psnr=[]
ssim=[]
for x in res:
    print(x["psnr"])
    psnr.append(x["psnr"])
    ssim.append(x["ssim"])
# Out:
# 18.053933875993916
# 16.471257339508547
# 18.735616535236986
# 19.70180800811794
# 20.81536720112569
# 20.444668927912414
# 21.145887614721566
# 23.74145451011649
# 25.411837184104936
# 23.889339218921908
# 25.12325479179926
# 16.6378309755444
# 24.000596152346304
# 24.237361986600888
# 25.641921562037695
# 24.450381043908468
# 25.837776228520195
# 24.29951807065927
# 25.125338534602342
# 24.355034725268993

# %%
import matplotlib.pyplot as plt

plt.plot(psnr[::2])

# %%
plt.plot(ssim[::2])

# %%
len(psnr)
# Out:
# 20
